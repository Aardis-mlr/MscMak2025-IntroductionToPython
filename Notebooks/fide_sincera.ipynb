# %%
x = 1
b = 3
while x <= 10:
    x += 1
    print("Yes")
# Out:
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes

# %%
i = 1

while i  <= 5:
    i = i + 1
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
password =""

while password != "admin25":
    password = (input("Enter password: "))
    
print("Access granted")
# Out:
# Access granted

# %%
password = ""

while password != "admin123":
    password = input("Enter password: ")

print("Access granted")
# Out:
# Access granted

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
